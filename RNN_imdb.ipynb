# %% [markdown]
# # RNN Implementation using (keras/tensorflow)

# %%
# import libraries
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense
from tensorflow.keras.preprocessing import sequence

import warnings
warnings.filterwarnings("ignore")

# %%
#load and preprocess data
#load dataset (only top 10,000 words)
max_features=10000
max_len=500 #cut reviews after 500 words
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=max_features)

#Pad sequence to ensure equal length
X_train = sequence.pad_sequences(X_train, maxlen=max_len)
X_test = sequence.pad_sequences(X_test, maxlen=max_len)
# Out:
# ...
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 34s 2us/step

# %%
#Build RNN model
model = Sequential()
model.add(Embedding(max_features,32)) 
model.add(SimpleRNN(32)) #Vanilla RNN player
model.add(Dense(1, activation = 'sigmoid'))

# %%
#compile the model
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
#train the model
history = model.fit(X_train, y_train, epochs= 5, batch_size =64, validation_split=0.2)
# Out:
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 54s 157ms/step - accuracy: 0.5948 - loss: 0.6576 - val_accuracy: 0.6744 - val_loss: 0.5977
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 50s 159ms/step - accuracy: 0.8001 - loss: 0.4413 - val_accuracy: 0.7910 - val_loss: 0.4581
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 53s 168ms/step - accuracy: 0.8385 - loss: 0.3728 - val_accuracy: 0.7240 - val_loss: 0.5453
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 78s 156ms/step - accuracy: 0.9116 - loss: 0.2357 - val_accuracy: 0.7786 - val_loss: 0.5353
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 49s 157ms/step - accuracy: 0.9679 - loss: 0.1016 - val_accuracy: 0.7876 - val_loss: 0.5896

# %%
#evalution the performance
test_loss,test_acc = model.evaluate(X_test, y_test)
print(f"Test Accuracy:{test_acc:.2f}")
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 25s 32ms/step - accuracy: 0.7906 - loss: 0.5844
# Test Accuracy:0.79
