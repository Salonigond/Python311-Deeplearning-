# %% [markdown]
# # Implementation of Lemmatizeation in NLP

# %%
#importing labraries
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
from nltk import pos_tag, word_tokenize

# %%
#download required libraries (run once)
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
#Initialize lemmatizer
lemmatizer=WordNetLemmatizer()

# %%
#Covert POS(part of speech) tag to wordnet fromat
def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
#Sample Text
text = "The striped bats are banding on their feet and ate best fishes"
#Tokenization
tokens = word_tokenize(text)
print(tokens)
# Out:
# ['The', 'striped', 'bats', 'are', 'banding', 'on', 'their', 'feet', 'and', 'ate', 'best', 'fishes']

# %%
#POS tagging
pos_tags= pos_tag(tokens)

# %%
#Lemmatization
lemmatized_words= []
for word, tag in pos_tags:
    wn_tag=get_wordnet_pos(tag)
    lemma= lemmatizer.lemmatize(word, pos=wn_tag)
    lemmatized_words.append(lemma)
print("Original:",tokens)
print("Lemmatized:",lemmatized_words)
# Out:
# Original: ['The', 'striped', 'bats', 'are', 'banding', 'on', 'their', 'feet', 'and', 'ate', 'best', 'fishes']
# Lemmatized: ['The', 'striped', 'bat', 'be', 'band', 'on', 'their', 'foot', 'and', 'ate', 'best', 'fish']

# %%
#
