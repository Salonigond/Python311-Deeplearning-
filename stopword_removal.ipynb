# %% [markdown]
# # Implementation of removeing stopwords with NLTK

# %%
#import Libraries
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
#sample text
#text = "This is a sample sentence showing stopword rempoval."
text= "I am software developer."
#get stopword and tokenize
stop_words= set(stopwords.words('english'))
tokens =word_tokenize(text.lower())

# %%
#remmove stopwords
filtered_tokens = [word for word in tokens if word not in stop_words]
print("original:", tokens)
print("Filtered:",filtered_tokens)
# Out:
# original: ['i', 'am', 'software', 'developer', '.']
# Filtered: ['software', 'developer', '.']
