# %% [markdown]
# # Implementation of tokenization
#
# ## Work tokenization

# %%
#importing labraries
import nltk
from nltk.tokenize import word_tokenize 
nltk.download('punkt')

text = "Tokenization is crucial for NLP"
word_tokens = word_tokenize(text)
print("Word Tokens:", word_tokens)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Word Tokens: ['Tokenization', 'is', 'crucial', 'for', 'NLP']

# %% [markdown]
# ## Subword tokenization

# %%
from tokenizers import Tokenizer
from tokenizers.models import BPE
from tokenizers.trainers import BpeTrainer
from tokenizers.pre_tokenizers import Whitespace

tokenizer = Tokenizer(BPE(unk_token="<unk>"))
tokenizer.pre_tokenizer= Whitespace()
data=["unhappiness", "happiness", "unhappy", "tokenization", "tokens", "learning NLP"]
trainer= BpeTrainer(vocab_size=50, special_tokens = ["<pad>", "<s>","</s>","<unk>","<mask>"])
tokenizer.train_from_iterator(data,trainer)
encode = tokenizer.encode("unhappiness")
print(encode.tokens)
print(encode.ids)
# Out:
# ['unhapp', 'iness']
# [34, 36]

# %% [markdown]
# ## Character Tokenization

# %%
text = "Tokenization" 
character_tokens=list(text)
print("Character Tokens:", character_tokens)
# Out:
# Character Tokens: ['T', 'o', 'k', 'e', 'n', 'i', 'z', 'a', 't', 'i', 'o', 'n']

# %% [markdown]
# ## Sentence Tokenization

# %%
from nltk.tokenize import sent_tokenize
text = "I am learning NLP. It is very intersting."
sentences = sent_tokenize(text)
print("Sentences Tokenization:", sentences)
# Out:
# Sentences Tokenization: ['I am learning NLP.', 'It is very intersting.']

# %% [markdown]
# ## Regex tokenization

# %%
import re
text = "Tokenization #1 is fun."
tokens = re.findall(r'\w+', text)
print(tokens)
# Out:
# ['Tokenization', '1', 'is', 'fun']

# %% [markdown]
# ## WhiteSpace tokenization

# %%
text = "I am learning NLP."
token = text.split()
print(token)
# Out:
# ['I', 'am', 'learning', 'NLP.']
